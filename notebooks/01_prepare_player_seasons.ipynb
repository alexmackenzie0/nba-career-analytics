# %% [markdown]
# import sys
# print(sys.executable)

# %%
import sys
print(sys.executable)
# Out:
# /Users/alexmackenzie/projects/nba-career-analytics/.venv/bin/python

# %%
pip install pandas numpy scikit-learn matplotlib seaborn plotly streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/alexmackenzie/projects/nba-career-analytics/data/raw/career_stats_2000_onward.csv")
df.head()
# Out:
#    PLAYER_ID SEASON_ID  LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203518   2016-17          0  1610612760               OKC        23.0
# 1     203518   2017-18          0  1610612760               OKC        24.0
# 2     203518   2018-19          0  1610612760               OKC        25.0
# 3    1630173   2020-21          0  1610612748               MIA        21.0
# 4    1630173   2021-22          0  1610612761               TOR        22.0
#
#    GP  GS   MIN  FGM  ...  DREB  REB  AST  STL  BLK  TOV   PF  PTS  \
# 0  68   6  1055  134  ...    68   86   40   37    8   33  114  406
# 1  75   8  1134  115  ...    88  114   28   38    8   25  124  353
# 2  31   2   588   56  ...    43   48   20   17    6   14   53  165
# 3  61   4   737  124  ...   135  208   29   20   28   43   91  304
# 4  73  28  1725  265  ...   327  473   82   37   41   84  151  664
#
#    SEASON_START_YEAR       PLAYER_NAME
# 0               2016      Alex Abrines
# ...

# %% [markdown]
# # 01 – Prepare Player Season Dataset
#
# Goal of this notebook:
# - Load raw NBA player season stats
# - Clean and standardize columns
# - Create an "impact" metric per season
# - Tag notable seasons with comments
# - Create per-player summary table (career length, labels, etc.)
# - Save processed data for the app

# %% [markdown]
# df.columns, df.dtypes

# %%
df.shape, df.head()
# Out:
# ((12930, 29),
#     PLAYER_ID SEASON_ID  LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  GP  GS   MIN  FGM  FGA  FG_PCT  FG3M  \
#  0     203518   2016-17          0  1610612760               OKC        23.0  68   6  1055  134  341   0.393    94
#  1     203518   2017-18          0  1610612760               OKC        24.0  75   8  1134  115  291   0.395    84
#  2     203518   2018-19          0  1610612760               OKC        25.0  31   2   588   56  157   0.357    41
#  3    1630173   2020-21          0  1610612748               MIA        21.0  61   4   737  124  228   0.544     0
#  4    1630173   2021-22          0  1610612761               TOR        22.0  73  28  1725  265  603   0.439    56
#
#     FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  PTS  SEASON_START_YEAR       PLAYER_NAME
#  0   247    0.381   44   49   0.898    18    68   86   40   37    8   33  114  406               2016      Alex Abrines
# ...
